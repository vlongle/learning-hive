# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("../../..")

# %%
import omegaconf
from shell.utils.experiment_utils import *
from shell.fleet.utils.fleet_utils import *
from shell.utils.metric import *
import matplotlib.pyplot as plt
from shell.fleet.network import TopologyGenerator
from sklearn.manifold import TSNE
import numpy as np
import pandas as pd
from shell.fleet.fleet import Agent, Fleet
from shell.fleet.data.data_utilize import *
from shell.fleet.data.recv import *

from sklearn.manifold import TSNE
from torchvision.utils import make_grid
from shell.fleet.data.data_utilize import *
import logging
from sklearn.metrics import f1_score
import os
from shell.fleet.data.recv_utils import *
from tqdm import tqdm
import argparse
from functools import partial
from torchvision.utils import make_grid
from shell.utils.oodloss import OODSeparationLoss
from pythresh.thresholds.dsn import DSN
from pythresh.thresholds.aucp import AUCP
from pythresh.thresholds.boot import BOOT
from pythresh.thresholds.zscore import ZSCORE
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from collections import defaultdict

logging.basicConfig(level=logging.INFO)

# %%
dataset = "mnist"
# algo = "modular"
algo = "monolithic"
prefilter_strategy = "oracle"
scorer = "cross_entropy"

experiment_folder = "experiment_results"
experiment_name = "vanilla_fix_bug_compute_loss_encodev2"

use_contrastive = True
num_trains_per_class = 64
seed = 0
num_neighbors = 10
parallel = False


save_dir = get_save_dir(experiment_folder, experiment_name,
                        dataset, algo, num_trains_per_class, use_contrastive, seed)
graph, datasets, NetCls, LearnerCls, net_cfg, agent_cfg, train_cfg, fleet_additional_cfg, cfg = get_cfg(
    save_dir)


# train_cfg['num_epochs'] = 10
train_cfg['component_update_freq'] = train_cfg['num_epochs']
# num_comms_per_task = 3 # should really add 1 because the last comm is kinda basically useless
num_comms_per_task = 6 # should really add 1 because the last comm is kinda basically useless
# for the current task.
comm_freq = train_cfg['num_epochs'] // num_comms_per_task

shared_memory_size = 200

cfg.sharing_strategy = DictConfig({
    "name": "recv_data",
    "scorer": scorer,
    "num_queries": 10,
    'num_data_neighbors': 5,
    'num_filter_neighbors': 5,
    'num_coms_per_round': 2,
    "query_score_threshold": 0.0,
    "shared_memory_size": shared_memory_size,
    # "shared_memory_size": 10,
    "comm_freq": comm_freq,
    "prefilter_strategy": prefilter_strategy,
    "use_ood_separation_loss": False,
})
# Out:
# INFO:root:Class sequence: [5 0 4 3 4 6 4 3 8 0 1 0 5 9 6 4 9 0 3 0]
# INFO:root:task 0 :(128, 1, 28, 28)
# INFO:root:task 1 :(128, 1, 28, 28)
# INFO:root:task 2 :(128, 1, 28, 28)
# INFO:root:task 3 :(128, 1, 28, 28)
# INFO:root:task 4 :(128, 1, 28, 28)
# {'train': {'component_update_freq': 100, 'num_epochs': 100, 'init_component_update_freq': 100, 'init_num_epochs': 100, 'save_freq': 20}, 'dataset': {'dataset_name': 'mnist', 'num_tasks': 10, 'num_classes_per_task': 2, 'with_replacement': True, 'num_trains_per_class': 64, 'num_vals_per_class': 50, 'remap_labels': True}, 'net': {'name': 'mlp', 'depth': 4, 'layer_size': 64, 'dropout': 0.0}, 'sharing_strategy': {'name': 'no_sharing', 'num_coms_per_round': 0}, 'seed': 0, 'algo': 'monolithic', 'job_name': 'mnist_monolithic_numtrain_64_contrastive', 'num_agents': 8, 'root_save_dir': 'experiment_results/vanilla_fix_bug_compute_loss_encodev2', 'parallel': True, 'num_init_tasks': 4, 'agent': {'save_dir': '${root_save_dir}/${job_name}/${dataset.dataset_name}/${algo}/seed_${seed}', 'batch_size': 64, 'memory_size': 32, 'improvement_threshold': 0.05, 'use_contrastive': True}}
# INFO:root:task 5 :(128, 1, 28, 28)
# INFO:root:task 6 :(128, 1, 28, 28)
# INFO:root:task 7 :(128, 1, 28, 28)
# INFO:root:task 8 :(128, 1, 28, 28)
# INFO:root:task 9 :(128, 1, 28, 28)
# INFO:root:Class sequence: [4 7 5 7 6 0 3 0 5 0 3 6 2 7 6 7 6 1 0 5]
# INFO:root:task 0 :(128, 1, 28, 28)
# INFO:root:task 1 :(128, 1, 28, 28)
# INFO:root:task 2 :(128, 1, 28, 28)
# INFO:root:task 3 :(128, 1, 28, 28)
# INFO:root:task 4 :(128, 1, 28, 28)
# INFO:root:task 5 :(128, 1, 28, 28)
# INFO:root:task 6 :(128, 1, 28, 28)
# INFO:root:task 7 :(128, 1, 28, 28)
# INFO:root:task 8 :(128, 1, 28, 28)
# INFO:root:task 9 :(128, 1, 28, 28)
# INFO:root:Class sequence: [6 7 7 8 4 1 1 8 6 1 6 4 5 7 8 0 2 3 0 3]
# INFO:root:task 0 :(128, 1, 28, 28)
# INFO:root:task 1 :(128, 1, 28, 28)
# INFO:root:task 2 :(128, 1, 28, 28)
# INFO:root:task 3 :(128, 1, 28, 28)
# INFO:root:task 4 :(128, 1, 28, 28)
# INFO:root:task 5 :(128, 1, 28, 28)
# INFO:root:task 6 :(128, 1, 28, 28)
# INFO:root:task 7 :(128, 1, 28, 28)
# INFO:root:task 8 :(128, 1, 28, 28)
# INFO:root:task 9 :(128, 1, 28, 28)
# INFO:root:Class sequence: [2 8 0 3 7 4 3 4 4 5 9 3 0 6 9 1 3 1 7 9]
# INFO:root:task 0 :(128, 1, 28, 28)
# INFO:root:task 1 :(128, 1, 28, 28)
# INFO:root:task 2 :(128, 1, 28, 28)
# INFO:root:task 3 :(128, 1, 28, 28)
# INFO:root:task 4 :(128, 1, 28, 28)
# INFO:root:task 5 :(128, 1, 28, 28)
# INFO:root:task 6 :(128, 1, 28, 28)
# INFO:root:task 7 :(128, 1, 28, 28)
# INFO:root:task 8 :(128, 1, 28, 28)
# INFO:root:task 9 :(128, 1, 28, 28)
# INFO:root:Class sequence: [0 3 0 2 9 7 0 9 2 1 7 6 8 6 1 8 6 4 9 8]
# INFO:root:task 0 :(128, 1, 28, 28)
# INFO:root:task 1 :(128, 1, 28, 28)
# INFO:root:task 2 :(128, 1, 28, 28)
# INFO:root:task 3 :(128, 1, 28, 28)
# INFO:root:task 4 :(128, 1, 28, 28)
# INFO:root:task 5 :(128, 1, 28, 28)
# INFO:root:task 6 :(128, 1, 28, 28)
# INFO:root:task 7 :(128, 1, 28, 28)
# INFO:root:task 8 :(128, 1, 28, 28)
# INFO:root:task 9 :(128, 1, 28, 28)
# INFO:root:Class sequence: [8 4 6 3 3 1 1 6 4 9 3 2 2 9 6 0 5 9 7 2]
# INFO:root:task 0 :(128, 1, 28, 28)
# INFO:root:task 1 :(128, 1, 28, 28)
# INFO:root:task 2 :(128, 1, 28, 28)
# INFO:root:task 3 :(128, 1, 28, 28)
# INFO:root:task 4 :(128, 1, 28, 28)
# INFO:root:task 5 :(128, 1, 28, 28)
# INFO:root:task 6 :(128, 1, 28, 28)
# INFO:root:task 7 :(128, 1, 28, 28)
# INFO:root:task 8 :(128, 1, 28, 28)
# INFO:root:task 9 :(128, 1, 28, 28)
# INFO:root:Class sequence: [7 5 8 4 6 9 8 3 4 6 1 3 3 1 4 1 9 2 6 2]
# INFO:root:task 0 :(128, 1, 28, 28)
# INFO:root:task 1 :(128, 1, 28, 28)
# INFO:root:task 2 :(128, 1, 28, 28)
# INFO:root:task 3 :(128, 1, 28, 28)
# INFO:root:task 4 :(128, 1, 28, 28)
# INFO:root:task 5 :(128, 1, 28, 28)
# INFO:root:task 6 :(128, 1, 28, 28)
# INFO:root:task 7 :(128, 1, 28, 28)
# INFO:root:task 8 :(128, 1, 28, 28)
# INFO:root:task 9 :(128, 1, 28, 28)
# INFO:root:Class sequence: [5 1 8 3 9 6 5 9 5 0 7 2 7 8 6 1 6 0 0 6]
# INFO:root:task 0 :(128, 1, 28, 28)
# INFO:root:task 1 :(128, 1, 28, 28)
# INFO:root:task 2 :(128, 1, 28, 28)
# INFO:root:task 3 :(128, 1, 28, 28)
# INFO:root:task 4 :(128, 1, 28, 28)
# INFO:root:task 5 :(128, 1, 28, 28)
# INFO:root:task 6 :(128, 1, 28, 28)
# INFO:root:task 7 :(128, 1, 28, 28)
# INFO:root:task 8 :(128, 1, 28, 28)
# INFO:root:task 9 :(128, 1, 28, 28)
# i_size 28
# num_classes 2
# net_cfg {'name': 'mlp', 'depth': 4, 'layer_size': 64, 'dropout': 0.0, 'i_size': 28, 'num_classes': 2, 'num_tasks': 10, 'num_init_tasks': 4, 'use_contrastive': True}
# <class 'shell.learners.er_nocomponents.NoComponentsER'>

# %%
AgentCls = get_agent_cls(cfg.sharing_strategy, cfg.algo, parallel)
FleetCls = get_fleet(cfg.sharing_strategy, parallel)

# %%
def setup_fleet(task_id=None): 
    fleet = FleetCls(graph, cfg.seed, datasets, cfg.sharing_strategy, AgentCls, NetCls=NetCls,
                    LearnerCls=LearnerCls, net_kwargs=net_cfg, agent_kwargs=agent_cfg,
                    train_kwargs=train_cfg, **fleet_additional_cfg)
    if task_id is not None:
        fleet.load_model_from_ckpoint(task_ids=task_id)
        fleet.update_replay_buffers(task_id)
    return fleet

# %%
fleet = setup_fleet(task_id=3)
# Out:
# INFO:root:Agent: node_id: 0, seed: 0
# INFO:root:Agent: node_id: 1, seed: 1000
# INFO:root:Agent: node_id: 2, seed: 2000
# INFO:root:Agent: node_id: 3, seed: 3000
# INFO:root:Agent: node_id: 4, seed: 4000
# INFO:root:Agent: node_id: 5, seed: 5000
# INFO:root:Agent: node_id: 6, seed: 6000
# INFO:root:Agent: node_id: 7, seed: 7000
# INFO:root:Created fleet with 8 agents
# INFO:root:Adding neighbors...
# INFO:root:Fleet initialized

# %%
# """
# Viz query. Each row is a task. Each column is a query.
# The label is {score}/{y}/{y_pred}, and
# `red` means y != y_pred, `green` means y == y_pred.
# """
# agent_id = 0
# query_task_id = 0
# agent = fleet.agents[agent_id]
# X_queries, y_queries, y_pred_queries, score_queries = agent.compute_query(task_id=4, debug_return=True)

# num_neighbors = len(X_queries.keys())
# num_queries = max([len(X_queries[i]) for i in range(num_neighbors)])
# fig, axes = plt.subplots(num_neighbors, num_queries, figsize=(num_queries*2, num_neighbors*2))

# rows = [f"task {task_id}" for task_id in range(num_neighbors)]
# pad = 0
# for ax, row in zip(axes[:,0], rows):
#     ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - pad, 0),
#                 xycoords=ax.yaxis.label, textcoords='offset points',
#                 size='large', ha='right', va='center', rotation=90)

# for task_id in range(num_neighbors):
#     for query_id in range(len(X_queries[task_id])):
#         ax = axes[task_id, query_id]
#         ax.set_xticks([])
#         ax.set_yticks([])

#         ax.imshow(X_queries[task_id][query_id].squeeze(), cmap="gray")
#         color = "green" if y_queries[task_id][query_id]  ==  y_pred_queries[task_id][query_id] else "red"
#         ax.set_title(f"{score_queries[task_id][query_id]:.2f}/{y_queries[task_id][query_id]}/{y_pred_queries[task_id][query_id]}",
#                      color=color)

   
# plt.tight_layout()

# %%
fleet.communicate(task_id=4)

# %%
# neighbor_data = [agent.incoming_extra_info[neigh_id]['X_neighbors'][query_task_id] for neigh_id in agent.incoming_data.keys()]
# neighbor_data = [task_data.reshape(-1, *task_data.shape[2:]) for task_data in neighbor_data]

# # Calculate number of rows (tasks) and columns (queries)
# num_neighbors = len(neighbor_data)
# num_queries = max([len(data) for data in neighbor_data])  # Assuming each task has a list of data

# # Create subplots
# fig, axes = plt.subplots(num_neighbors, num_queries, figsize=(num_queries * 2, num_neighbors * 2))

# # Set row labels
# rows = [f"neighbor {neigh_id}" for neigh_id in agent.incoming_data.keys()]
# pad = 0
# for ax, row in zip(axes[:, 0], rows):
#     ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - pad, 0),
#                 xycoords=ax.yaxis.label, textcoords='offset points',
#                 size='large', ha='right', va='center', rotation=90)

# # Plot data
# for task_id, task_data in enumerate(neighbor_data):
#     for query_id in range(len(task_data)):
#         ax = axes[task_id, query_id]
#         ax.set_xticks([])
#         ax.set_yticks([])

#         ax.imshow(task_data[query_id].squeeze(), cmap="gray")

# plt.tight_layout()

# %%
# replay = agent.agent.shared_replay_buffers[query_task_id]
# plt.imshow(make_grid(replay.tensors[0][:len(replay)]).permute(1,2,0));

# %% [markdown]
# ## The performance of baseline fleet

# %%
test_task_id = 4
fleet = setup_fleet(task_id=test_task_id)
baseline_perfs = fleet.eval_test(test_task_id)
# Out:
# INFO:root:Agent: node_id: 0, seed: 0
# INFO:root:Agent: node_id: 1, seed: 1000
# INFO:root:Agent: node_id: 2, seed: 2000
# INFO:root:Agent: node_id: 3, seed: 3000
# INFO:root:Agent: node_id: 4, seed: 4000
# INFO:root:Agent: node_id: 5, seed: 5000
# INFO:root:Agent: node_id: 6, seed: 6000
# INFO:root:Agent: node_id: 7, seed: 7000
# INFO:root:Created fleet with 8 agents
# INFO:root:Adding neighbors...
# INFO:root:Fleet initialized

# %%
df = pd.DataFrame(baseline_perfs)
df.columns = df.columns.astype(str)

task_stats = df.agg(["mean", "std"])
plt.bar(task_stats.columns, task_stats.loc['mean'], yerr=task_stats.loc['std'], capsize=5, color='skyblue')
plt.xlabel('Tasks')
plt.ylabel('Average Performance')
plt.title('Baseline Performance')
plt.ylim(0.4, 1.0)  
plt.show()

# %%
task_stats
# Out:
#              0         1         2         3         4       avg
# mean  0.937849  0.948558  0.936395  0.944152  0.960156  0.945422
# std   0.035141  0.018218  0.040616  0.038275  0.017126  0.012248

# %%
# len(agent.dataset.trainset[task_id].tensors)

# %%
# from shell.fleet.fleet import CustomConcatDataset
# from shell.datasets.datasets import get_custom_tensordataset
# from torch.utils.data.dataset import ConcatDataset

# task_id = 4
# fleet = setup_fleet(task_id=task_id)
# agent = fleet.agents[0]
# dataset = deepcopy(agent.dataset.trainset[task_id])

# n = 100
# X = torch.zeros((n, 1, 28, 28))
# y = torch.zeros(n, dtype=torch.long)

# agent.agent.shared_replay_buffers[task_id] = ReplayBufferReservoir(
#             10000, task_id)
# agent.agent.shared_replay_buffers[task_id].push(
#     X, y
# )

# agent.agent.make_shared_memory_loaders(
#             batch_size=agent.batch_size)

# if task_id in agent.agent.shared_memory_loaders:
#     print("adding shared memory")
#     loader = agent.agent.shared_memory_loaders[task_id]
#     shared_tensors = loader.dataset.get_tensors()  # X, y, t
#     # throw away the task id
#     shared_tensors = shared_tensors[:2]
#     dataset = CustomConcatDataset(
#         dataset.tensors, shared_tensors)
#     dataset = get_custom_tensordataset(dataset.tensors, name=agent.dataset.name,
#                                         use_contrastive=agent.agent.use_contrastive)
                                                



# # dataset.tensors = dataset.tensors + \
# #             (torch.full((len(dataset),), task_id, dtype=int),)

# # tmp_dataset = dataset

# # mega_dataset = ConcatDataset(
# #             [get_custom_tensordataset(loader.dataset.get_tensors(), name=agent.dataset.name,
# #                                       use_contrastive=agent.agent.use_contrastive) for t, loader in agent.agent.memory_loaders.items() if t != task_id] + [tmp_dataset]
# #             + [get_custom_tensordataset(loader.dataset.get_tensors(), name=agent.agent.dataset_name,
# #                                         use_contrastive=agent.agent.use_contrastive) for t, loader in agent.agent.shared_memory_loaders.items()
# #                if t != task_id]
# #         )

# # mega_dataset = dataset

# # mega_loader = torch.utils.data.DataLoader(mega_dataset,
# #                                                   batch_size=32,
# #                                                   shuffle=True,
# #                                                   num_workers=0,
# #                                                   pin_memory=True
# #                                                   )

# %%
# len(dataset)

# %%
# for X, Y, t in mega_loader:
#     print('X', type(X), X[0].shape, X[1].shape)
#     print(Y.shape, t.shape)

# %%
# len(mega_dataset)

# %%
# dataset.tensors[0].shape, dataset.tensors[1].shape, dataset.tensors[2].shape

# %%
# len(agent.agent.shared_replay_buffers[task_id].get_tensors())

# %% [markdown]
# ## Receiver Sharing

# %%
AgentCls = get_agent_cls(cfg.sharing_strategy, cfg.algo, parallel=True)
FleetCls = get_fleet(cfg.sharing_strategy, parallel=True)

fleet = setup_fleet(task_id=test_task_id-1)
before_sharing_and_learn = fleet.eval_test(test_task_id)
# Out:
# INFO:root:No. gpus per agent: 0.25
# 2024-02-05 11:23:47,029	INFO worker.py:1544 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# (ParallelRecvDataAgent pid=1473231) INFO:root:Agent: node_id: 0, seed: 0
# INFO:root:Created fleet with 8 agents
# INFO:root:Adding neighbors...
# (ParallelRecvDataAgent pid=1473232) INFO:root:Agent: node_id: 1, seed: 1000
# (ParallelRecvDataAgent pid=1473233) INFO:root:Agent: node_id: 2, seed: 2000
# (ParallelRecvDataAgent pid=1473256) INFO:root:Agent: node_id: 3, seed: 3000
# (ParallelRecvDataAgent pid=1473345) INFO:root:Agent: node_id: 4, seed: 4000
# (ParallelRecvDataAgent pid=1473474) INFO:root:Agent: node_id: 6, seed: 6000
# (ParallelRecvDataAgent pid=1473413) INFO:root:Agent: node_id: 5, seed: 5000
# (ParallelRecvDataAgent pid=1473537) INFO:root:Agent: node_id: 7, seed: 7000
# INFO:root:Fleet initialized

# %%
df = pd.DataFrame(before_sharing_and_learn)
df.columns = df.columns.astype(str)

task_stats = df.agg(["mean", "std"])
plt.bar(task_stats.columns, task_stats.loc['mean'], yerr=task_stats.loc['std'], capsize=5, color='skyblue')
plt.xlabel('Tasks')
plt.ylabel('Average Performance')
plt.title('Baseline Performance')
plt.ylim(0.4, 1.0)  
plt.show()

# %%
print(fleet.get_save_dir())
fleet.change_save_dir('experiment_results/test_recv_global_labels')
print(fleet.get_save_dir())
# Out:
# ['experiment_results/vanilla_fix_bug_compute_loss_encodev2/mnist_monolithic_numtrain_64_contrastive/mnist/monolithic/seed_0/agent_0', 'experiment_results/vanilla_fix_bug_compute_loss_encodev2/mnist_monolithic_numtrain_64_contrastive/mnist/monolithic/seed_0/agent_1', 'experiment_results/vanilla_fix_bug_compute_loss_encodev2/mnist_monolithic_numtrain_64_contrastive/mnist/monolithic/seed_0/agent_2', 'experiment_results/vanilla_fix_bug_compute_loss_encodev2/mnist_monolithic_numtrain_64_contrastive/mnist/monolithic/seed_0/agent_3', 'experiment_results/vanilla_fix_bug_compute_loss_encodev2/mnist_monolithic_numtrain_64_contrastive/mnist/monolithic/seed_0/agent_4', 'experiment_results/vanilla_fix_bug_compute_loss_encodev2/mnist_monolithic_numtrain_64_contrastive/mnist/monolithic/seed_0/agent_5', 'experiment_results/vanilla_fix_bug_compute_loss_encodev2/mnist_monolithic_numtrain_64_contrastive/mnist/monolithic/seed_0/agent_6', 'experiment_results/vanilla_fix_bug_compute_loss_encodev2/mnist_monolithic_numtrain_64_contrastive/mnist/monolithic/seed_0/agent_7']
# ['experiment_results/test_recv_global_labels/agent_0', 'experiment_results/test_recv_global_labels/agent_1', 'experiment_results/test_recv_global_labels/agent_2', 'experiment_results/test_recv_global_labels/agent_3', 'experiment_results/test_recv_global_labels/agent_4', 'experiment_results/test_recv_global_labels/agent_5', 'experiment_results/test_recv_global_labels/agent_6', 'experiment_results/test_recv_global_labels/agent_7']

# %%
fleet.train_and_comm(task_id=test_task_id)
# Out:
# (ParallelRecvDataAgent pid=1473231) INFO:root:epochs: 0, training task: 4
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 0	loss: 0.42918714	acc: 0.976
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 1	loss: 0.34338886	acc: 0.976
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 2	loss: 0.39248622	acc: 0.961
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 3	loss: 0.36483764	acc: 0.970
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 4	loss: 0.70036920	acc: 0.390
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: avg	loss: 0.44605381	acc: 0.855
# (ParallelRecvDataAgent pid=1473232) INFO:root:epochs: 0, training task: 4
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 0	loss: 0.41123773	acc: 0.962
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 1	loss: 0.39855686	acc: 0.956
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 2	loss: 0.42687120	acc: 0.954
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 3	loss: 0.40204477	acc: 0.950
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 4	loss: 0.68465778	acc: 0.524
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: avg	loss: 0.46467367	acc: 0.869
# (ParallelRecvDataAgent pid=1473233) INFO:root:epochs: 0, training task: 4
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 0	loss: 0.40699714	acc: 0.941
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 1	loss: 0.42925124	acc: 0.939
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 2	loss: 0.40625733	acc: 0.972
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 3	loss: 0.37812681	acc: 0.975
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 4	loss: 0.67808108	acc: 0.976
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: avg	loss: 0.45974272	acc: 0.961
# (ParallelRecvDataAgent pid=1473256) INFO:root:epochs: 0, training task: 4
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 0	loss: 0.44462026	acc: 0.929
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 1	loss: 0.40856244	acc: 0.957
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 2	loss: 0.39618491	acc: 0.958
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 3	loss: 0.40671727	acc: 0.957
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 4	loss: 0.69710163	acc: 0.524
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: avg	loss: 0.47063730	acc: 0.865
# (ParallelRecvDataAgent pid=1473345) INFO:root:epochs: 0, training task: 4
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 0	loss: 0.35749244	acc: 0.979
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 1	loss: 0.39836493	acc: 0.964
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 2	loss: 0.45656603	acc: 0.915
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 3	loss: 0.36512432	acc: 0.972
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 4	loss: 0.69905012	acc: 0.476
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: avg	loss: 0.45531957	acc: 0.861
# (ParallelRecvDataAgent pid=1473474) INFO:root:epochs: 0, training task: 4
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 0	loss: 0.38720135	acc: 0.959
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 1	loss: 0.40702449	acc: 0.950
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 2	loss: 0.42665156	acc: 0.943
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 3	loss: 0.45815642	acc: 0.919
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 4	loss: 0.70830269	acc: 0.506
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: avg	loss: 0.47746730	acc: 0.855
# (ParallelRecvDataAgent pid=1473413) INFO:root:epochs: 0, training task: 4
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 0	loss: 0.40130494	acc: 0.950
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 1	loss: 0.39176059	acc: 0.983
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 2	loss: 0.41176403	acc: 0.983
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 3	loss: 0.39507382	acc: 0.995
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 4	loss: 0.69288244	acc: 0.493
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: avg	loss: 0.45855716	acc: 0.881
# (ParallelRecvDataAgent pid=1473537) INFO:root:epochs: 0, training task: 4
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 0	loss: 0.40109092	acc: 0.957
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 1	loss: 0.42245722	acc: 0.949
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 2	loss: 0.38883644	acc: 0.968
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 3	loss: 0.39808667	acc: 0.961
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 4	loss: 0.70339186	acc: 0.476
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: avg	loss: 0.46277262	acc: 0.862
# (ParallelRecvDataAgent pid=1473231) INFO:root:epochs: 1, training task: 4
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 0	loss: 0.40027271	acc: 0.981
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 1	loss: 0.40989268	acc: 0.897
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 2	loss: 0.45203771	acc: 0.861
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 3	loss: 0.43644696	acc: 0.877
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 4	loss: 0.70634927	acc: 0.095
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: avg	loss: 0.48099986	acc: 0.742
# (ParallelRecvDataAgent pid=1473232) INFO:root:epochs: 1, training task: 4
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 0	loss: 0.40789089	acc: 0.958
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 1	loss: 0.39582258	acc: 0.946
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 2	loss: 0.42348372	acc: 0.956
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 3	loss: 0.39539034	acc: 0.950
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 4	loss: 0.67796420	acc: 0.524
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: avg	loss: 0.46011034	acc: 0.867
# (ParallelRecvDataAgent pid=1473233) INFO:root:epochs: 1, training task: 4
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 0	loss: 0.40434318	acc: 0.946
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 1	loss: 0.42657441	acc: 0.943
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 2	loss: 0.40879448	acc: 0.956
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 3	loss: 0.36832993	acc: 0.975
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 4	loss: 0.67202786	acc: 0.979
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: avg	loss: 0.45601397	acc: 0.960
# (ParallelRecvDataAgent pid=1473256) INFO:root:epochs: 1, training task: 4
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 0	loss: 0.48587840	acc: 0.907
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 1	loss: 0.44809058	acc: 0.953
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 2	loss: 0.42111507	acc: 0.956
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 3	loss: 0.43931672	acc: 0.954
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 4	loss: 0.69369550	acc: 0.524
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: avg	loss: 0.49761926	acc: 0.859
# (ParallelRecvDataAgent pid=1473345) INFO:root:epochs: 1, training task: 4
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 0	loss: 0.37017343	acc: 0.969
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 1	loss: 0.39644517	acc: 0.964
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 2	loss: 0.44423525	acc: 0.916
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 3	loss: 0.37206274	acc: 0.965
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 4	loss: 0.69551231	acc: 0.476
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: avg	loss: 0.45568578	acc: 0.858
# (ParallelRecvDataAgent pid=1473413) INFO:root:epochs: 1, training task: 4
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 0	loss: 0.44636596	acc: 0.898
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 1	loss: 0.41597550	acc: 0.971
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 2	loss: 0.42900906	acc: 0.981
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 3	loss: 0.39067818	acc: 0.994
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 4	loss: 0.68561314	acc: 0.493
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: avg	loss: 0.47352837	acc: 0.867
# (ParallelRecvDataAgent pid=1473474) INFO:root:epochs: 1, training task: 4
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 0	loss: 0.38213701	acc: 0.955
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 1	loss: 0.40887440	acc: 0.937
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 2	loss: 0.39859628	acc: 0.961
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 3	loss: 0.45922484	acc: 0.902
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 4	loss: 0.70278961	acc: 0.506
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: avg	loss: 0.47032443	acc: 0.852
# (ParallelRecvDataAgent pid=1473537) INFO:root:epochs: 1, training task: 4
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 0	loss: 0.41002077	acc: 0.986
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 1	loss: 0.46557238	acc: 0.911
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 2	loss: 0.44410860	acc: 0.925
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 3	loss: 0.43994481	acc: 0.945
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 4	loss: 0.70144793	acc: 0.476
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: avg	loss: 0.49221890	acc: 0.849
# (ParallelRecvDataAgent pid=1473231) INFO:root:epochs: 16, training task: 4
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 0	loss: 0.38364855	acc: 0.978
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 1	loss: 0.33650633	acc: 0.950
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 2	loss: 0.37391795	acc: 0.939
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 3	loss: 0.36896627	acc: 0.921
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 4	loss: 0.63489365	acc: 0.906
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: avg	loss: 0.41958655	acc: 0.939
# (ParallelRecvDataAgent pid=1473256) INFO:root:epochs: 16, training task: 4
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 0	loss: 0.54055796	acc: 0.715
# (ParallelRecvDataAgent pid=1473345) INFO:root:epochs: 16, training task: 4
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 0	loss: 0.34335289	acc: 0.962
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 1	loss: 0.34720926	acc: 0.961
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 2	loss: 0.46053325	acc: 0.848
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 3	loss: 0.35405708	acc: 0.949
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 4	loss: 0.60016441	acc: 0.947
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 1	loss: 0.39224670	acc: 0.969
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: avg	loss: 0.42106338	acc: 0.933
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 2	loss: 0.34838244	acc: 0.965
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 3	loss: 0.33434180	acc: 0.985
# (ParallelRecvDataAgent pid=1473232) INFO:root:epochs: 16, training task: 4
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 0	loss: 0.37661501	acc: 0.946
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 4	loss: 0.60723096	acc: 0.906
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 1	loss: 0.35427731	acc: 0.946
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: avg	loss: 0.44455197	acc: 0.908
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 2	loss: 0.37206220	acc: 0.948
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 3	loss: 0.35678918	acc: 0.933
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 4	loss: 0.58663303	acc: 0.954
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: avg	loss: 0.40927535	acc: 0.945
# (ParallelRecvDataAgent pid=1473233) INFO:root:epochs: 16, training task: 4
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 0	loss: 0.34887783	acc: 0.939
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 1	loss: 0.36142044	acc: 0.942
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 2	loss: 0.32308566	acc: 0.973
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 3	loss: 0.29886981	acc: 0.979
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 4	loss: 0.55993472	acc: 0.989
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: avg	loss: 0.37843769	acc: 0.964
# (ParallelRecvDataAgent pid=1473413) INFO:root:epochs: 16, training task: 4
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 0	loss: 0.40239122	acc: 0.896
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 1	loss: 0.35281385	acc: 0.980
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 2	loss: 0.38313620	acc: 0.981
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 3	loss: 0.34004425	acc: 0.994
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 4	loss: 0.60711243	acc: 0.853
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: avg	loss: 0.41709959	acc: 0.941
# (ParallelRecvDataAgent pid=1473474) INFO:root:epochs: 16, training task: 4
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 0	loss: 0.34514033	acc: 0.945
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 1	loss: 0.34135548	acc: 0.956
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 2	loss: 0.35876944	acc: 0.949
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 3	loss: 0.41264952	acc: 0.909
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 4	loss: 0.59726206	acc: 0.941
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: avg	loss: 0.41103537	acc: 0.940
# (ParallelRecvDataAgent pid=1473537) INFO:root:epochs: 16, training task: 4
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 0	loss: 0.34532876	acc: 0.960
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 1	loss: 0.41921713	acc: 0.939
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 2	loss: 0.39245939	acc: 0.935
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 3	loss: 0.35041470	acc: 0.959
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 4	loss: 0.61662739	acc: 0.850
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: avg	loss: 0.42480947	acc: 0.928
# training from 0 to 16
# comm at epoch 16
# (ParallelRecvDataAgent pid=1473233) INFO:root:epochs: 21, training task: 4
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 0	loss: 0.38791603	acc: 0.969
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 1	loss: 0.52425292	acc: 0.788
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 2	loss: 0.61380293	acc: 0.611
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 3	loss: 0.49065489	acc: 0.808
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 4	loss: 0.57597609	acc: 0.954
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: avg	loss: 0.51852057	acc: 0.826
# (ParallelRecvDataAgent pid=1473256) INFO:root:epochs: 21, training task: 4
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 0	loss: 0.48536124	acc: 0.900
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 1	loss: 0.46564520	acc: 0.940
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 2	loss: 0.38385224	acc: 0.961
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 3	loss: 0.38070334	acc: 0.982
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 4	loss: 0.59186753	acc: 0.923
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: avg	loss: 0.46148591	acc: 0.941
# (ParallelRecvDataAgent pid=1473232) INFO:root:epochs: 21, training task: 4
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 0	loss: 0.48265616	acc: 0.896
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 1	loss: 0.42249706	acc: 0.955
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 2	loss: 0.43855817	acc: 0.942
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 3	loss: 0.42095580	acc: 0.941
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 4	loss: 0.60210880	acc: 0.958
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: avg	loss: 0.47335520	acc: 0.938
# (ParallelRecvDataAgent pid=1473345) INFO:root:epochs: 21, training task: 4
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 0	loss: 0.51841682	acc: 0.779
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 1	loss: 0.43324924	acc: 0.912
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 2	loss: 0.47703024	acc: 0.889
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 3	loss: 0.40789643	acc: 0.958
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 4	loss: 0.58764834	acc: 0.928
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: avg	loss: 0.48484821	acc: 0.893
# (ParallelRecvDataAgent pid=1473537) INFO:root:epochs: 21, training task: 4
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 0	loss: 0.37165560	acc: 0.971
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 1	loss: 0.44436800	acc: 0.864
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 2	loss: 0.45373682	acc: 0.897
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 3	loss: 0.39633279	acc: 0.936
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 4	loss: 0.61349873	acc: 0.919
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: avg	loss: 0.45591839	acc: 0.918
# (ParallelRecvDataAgent pid=1473474) INFO:root:epochs: 21, training task: 4
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 0	loss: 0.41730960	acc: 0.925
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 1	loss: 0.40902822	acc: 0.947
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 2	loss: 0.44198784	acc: 0.931
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 3	loss: 0.42933493	acc: 0.920
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 4	loss: 0.61095367	acc: 0.934
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: avg	loss: 0.46172285	acc: 0.931
# (ParallelRecvDataAgent pid=1473413) INFO:root:epochs: 21, training task: 4
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 0	loss: 0.41766561	acc: 0.919
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 1	loss: 0.38595734	acc: 0.967
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 2	loss: 0.48775282	acc: 0.936
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 3	loss: 0.43058185	acc: 0.987
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 4	loss: 0.59435902	acc: 0.891
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: avg	loss: 0.46326333	acc: 0.940
# (ParallelRecvDataAgent pid=1473231) INFO:root:epochs: 21, training task: 4
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 0	loss: 0.35828803	acc: 0.974
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 1	loss: 0.36990747	acc: 0.948
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 2	loss: 0.42343500	acc: 0.899
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 3	loss: 0.37072998	acc: 0.960
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 4	loss: 0.58284743	acc: 0.917
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: avg	loss: 0.42104158	acc: 0.940
# training from 16 to 32
# comm at epoch 32
# (ParallelRecvDataAgent pid=1473256) INFO:root:epochs: 41, training task: 4
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 0	loss: 0.48838638	acc: 0.803
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 1	loss: 0.42709958	acc: 0.862
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 2	loss: 0.38037185	acc: 0.880
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 3	loss: 0.33469124	acc: 0.976
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 4	loss: 0.48976627	acc: 0.955
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: avg	loss: 0.42406306	acc: 0.895
# (ParallelRecvDataAgent pid=1473413) INFO:root:epochs: 41, training task: 4
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 0	loss: 0.31698706	acc: 0.945
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 1	loss: 0.34333028	acc: 0.973
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 2	loss: 0.37095377	acc: 0.958
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 3	loss: 0.30680823	acc: 0.985
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 4	loss: 0.47843679	acc: 0.905
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: avg	loss: 0.36330323	acc: 0.953
# (ParallelRecvDataAgent pid=1473537) INFO:root:epochs: 41, training task: 4
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 0	loss: 0.25782916	acc: 0.982
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 1	loss: 0.30923315	acc: 0.943
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 2	loss: 0.30187844	acc: 0.954
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 3	loss: 0.28138162	acc: 0.955
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 4	loss: 0.49415355	acc: 0.917
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: avg	loss: 0.32889518	acc: 0.950
# (ParallelRecvDataAgent pid=1473345) INFO:root:epochs: 41, training task: 4
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 0	loss: 0.30799690	acc: 0.974
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 1	loss: 0.33543753	acc: 0.898
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 2	loss: 0.36552848	acc: 0.899
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 3	loss: 0.29149625	acc: 0.931
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 4	loss: 0.44726351	acc: 0.946
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: avg	loss: 0.34954453	acc: 0.930
# (ParallelRecvDataAgent pid=1473233) INFO:root:epochs: 41, training task: 4
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 0	loss: 0.31441053	acc: 0.956
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 1	loss: 0.36101767	acc: 0.938
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 2	loss: 0.45889606	acc: 0.905
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 3	loss: 0.30725273	acc: 0.970
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 4	loss: 0.44701776	acc: 0.955
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: avg	loss: 0.37771895	acc: 0.945
# (ParallelRecvDataAgent pid=1473474) INFO:root:epochs: 41, training task: 4
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 0	loss: 0.36945999	acc: 0.916
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 1	loss: 0.34887131	acc: 0.943
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 2	loss: 0.35144481	acc: 0.925
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 3	loss: 0.33611441	acc: 0.919
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 4	loss: 0.53420022	acc: 0.954
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: avg	loss: 0.38801815	acc: 0.931
# (ParallelRecvDataAgent pid=1473232) INFO:root:epochs: 41, training task: 4
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 0	loss: 0.35281149	acc: 0.925
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 1	loss: 0.33055337	acc: 0.940
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 2	loss: 0.30335218	acc: 0.961
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 3	loss: 0.33392989	acc: 0.925
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 4	loss: 0.50555585	acc: 0.942
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: avg	loss: 0.36524056	acc: 0.938
# (ParallelRecvDataAgent pid=1473231) INFO:root:epochs: 41, training task: 4
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 0	loss: 0.36589800	acc: 0.901
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 1	loss: 0.22473526	acc: 0.968
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 2	loss: 0.26211197	acc: 0.957
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 3	loss: 0.23380814	acc: 0.980
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 4	loss: 0.46055117	acc: 0.920
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: avg	loss: 0.30942091	acc: 0.945
# training from 32 to 48
# comm at epoch 48
# (ParallelRecvDataAgent pid=1473256) INFO:root:epochs: 61, training task: 4
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 0	loss: 0.41625596	acc: 0.846
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 1	loss: 0.31659419	acc: 0.977
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 2	loss: 0.33860225	acc: 0.888
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 3	loss: 0.28193937	acc: 0.972
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 4	loss: 0.39480955	acc: 0.947
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: avg	loss: 0.34964026	acc: 0.926
# (ParallelRecvDataAgent pid=1473345) INFO:root:epochs: 61, training task: 4
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 0	loss: 0.24797176	acc: 0.971
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 1	loss: 0.23434334	acc: 0.934
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 2	loss: 0.32603120	acc: 0.885
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 3	loss: 0.27344134	acc: 0.905
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 4	loss: 0.37730888	acc: 0.931
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: avg	loss: 0.29181931	acc: 0.926
# (ParallelRecvDataAgent pid=1473413) INFO:root:epochs: 61, training task: 4
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 0	loss: 0.22428886	acc: 0.948
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 1	loss: 0.22319537	acc: 0.977
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 2	loss: 0.23196151	acc: 0.979
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 3	loss: 0.23663263	acc: 0.985
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 4	loss: 0.35165553	acc: 0.915
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: avg	loss: 0.25354678	acc: 0.961
# (ParallelRecvDataAgent pid=1473474) INFO:root:epochs: 61, training task: 4
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 0	loss: 0.27735439	acc: 0.941
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 1	loss: 0.22190083	acc: 0.956
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 2	loss: 0.27123033	acc: 0.914
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 3	loss: 0.26809253	acc: 0.911
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 4	loss: 0.43241489	acc: 0.952
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: avg	loss: 0.29419859	acc: 0.935
# (ParallelRecvDataAgent pid=1473233) INFO:root:epochs: 61, training task: 4
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 0	loss: 0.22292480	acc: 0.966
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 1	loss: 0.28108300	acc: 0.944
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 2	loss: 0.30057426	acc: 0.945
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 3	loss: 0.24812425	acc: 0.959
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 4	loss: 0.36329601	acc: 0.973
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: avg	loss: 0.28320046	acc: 0.957
# (ParallelRecvDataAgent pid=1473232) INFO:root:epochs: 61, training task: 4
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 0	loss: 0.27806288	acc: 0.923
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 1	loss: 0.29961906	acc: 0.914
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 2	loss: 0.20728338	acc: 0.964
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 3	loss: 0.29489658	acc: 0.927
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 4	loss: 0.44745895	acc: 0.921
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: avg	loss: 0.30546417	acc: 0.930
# (ParallelRecvDataAgent pid=1473537) INFO:root:epochs: 61, training task: 4
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 0	loss: 0.19965764	acc: 0.979
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 1	loss: 0.23673953	acc: 0.942
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 2	loss: 0.20807123	acc: 0.965
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 3	loss: 0.20066553	acc: 0.948
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 4	loss: 0.47375406	acc: 0.761
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: avg	loss: 0.26377760	acc: 0.919
# (ParallelRecvDataAgent pid=1473231) INFO:root:epochs: 61, training task: 4
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 0	loss: 0.25057568	acc: 0.945
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 1	loss: 0.19301973	acc: 0.968
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 2	loss: 0.20877335	acc: 0.962
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 3	loss: 0.19353610	acc: 0.969
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 4	loss: 0.28928001	acc: 0.944
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: avg	loss: 0.22703697	acc: 0.958
# training from 48 to 64
# comm at epoch 64
# training from 64 to 80
# comm at epoch 80
# (ParallelRecvDataAgent pid=1473256) INFO:root:epochs: 81, training task: 4
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 0	loss: 0.37687398	acc: 0.866
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 1	loss: 0.30524565	acc: 0.924
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 2	loss: 0.24434966	acc: 0.943
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 3	loss: 0.27115890	acc: 0.966
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 4	loss: 0.34022276	acc: 0.955
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: avg	loss: 0.30757019	acc: 0.931
# (ParallelRecvDataAgent pid=1473345) INFO:root:epochs: 81, training task: 4
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 0	loss: 0.18798523	acc: 0.968
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 1	loss: 0.20915068	acc: 0.931
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 2	loss: 0.27911048	acc: 0.900
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 3	loss: 0.18840839	acc: 0.937
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 4	loss: 0.32390848	acc: 0.929
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: avg	loss: 0.23771265	acc: 0.933
# (ParallelRecvDataAgent pid=1473537) INFO:root:epochs: 81, training task: 4
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 0	loss: 0.18292995	acc: 0.977
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 1	loss: 0.24506114	acc: 0.926
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 2	loss: 0.17606927	acc: 0.966
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 3	loss: 0.19409629	acc: 0.947
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 4	loss: 0.28997165	acc: 0.934
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: avg	loss: 0.21762566	acc: 0.950
# (ParallelRecvDataAgent pid=1473232) INFO:root:epochs: 81, training task: 4
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 0	loss: 0.28763509	acc: 0.891
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 1	loss: 0.20116253	acc: 0.953
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 2	loss: 0.17275690	acc: 0.964
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 3	loss: 0.25386555	acc: 0.933
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 4	loss: 0.44579313	acc: 0.876
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: avg	loss: 0.27224264	acc: 0.923
# (ParallelRecvDataAgent pid=1473233) INFO:root:epochs: 81, training task: 4
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 0	loss: 0.19784938	acc: 0.956
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 1	loss: 0.22318882	acc: 0.943
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 2	loss: 0.16295561	acc: 0.982
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 3	loss: 0.14181347	acc: 0.975
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 4	loss: 0.24110095	acc: 0.982
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: avg	loss: 0.19338165	acc: 0.968
# (ParallelRecvDataAgent pid=1473413) INFO:root:epochs: 81, training task: 4
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 0	loss: 0.19508864	acc: 0.944
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 1	loss: 0.14701742	acc: 0.975
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 2	loss: 0.14462958	acc: 0.986
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 3	loss: 0.16798721	acc: 0.992
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 4	loss: 0.25273908	acc: 0.933
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: avg	loss: 0.18149239	acc: 0.966
# (ParallelRecvDataAgent pid=1473474) INFO:root:epochs: 81, training task: 4
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 0	loss: 0.20122778	acc: 0.953
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 1	loss: 0.16802938	acc: 0.951
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 2	loss: 0.17332072	acc: 0.955
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 3	loss: 0.23750775	acc: 0.915
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 4	loss: 0.32410418	acc: 0.969
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: avg	loss: 0.22083796	acc: 0.948
# (ParallelRecvDataAgent pid=1473231) INFO:root:epochs: 81, training task: 4
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 0	loss: 0.24401622	acc: 0.935
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 1	loss: 0.13175742	acc: 0.977
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 2	loss: 0.15468659	acc: 0.969
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 3	loss: 0.13253185	acc: 0.977
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 4	loss: 0.17532421	acc: 0.970
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: avg	loss: 0.16766326	acc: 0.966
# training from 80 to 96
# comm at epoch 96
# (ParallelRecvDataAgent pid=1473256) INFO:root:epochs: 101, training task: 4
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 0	loss: 0.29318926	acc: 0.911
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 1	loss: 0.20081101	acc: 0.965
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 2	loss: 0.23826517	acc: 0.922
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 3	loss: 0.20859286	acc: 0.963
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: 4	loss: 0.28235783	acc: 0.957
# (ParallelRecvDataAgent pid=1473256) INFO:root:	task: avg	loss: 0.24464323	acc: 0.944
# (ParallelRecvDataAgent pid=1473345) INFO:root:epochs: 101, training task: 4
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 0	loss: 0.19309318	acc: 0.956
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 1	loss: 0.17207698	acc: 0.935
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 2	loss: 0.26311218	acc: 0.902
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 3	loss: 0.18273706	acc: 0.933
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: 4	loss: 0.25179594	acc: 0.944
# (ParallelRecvDataAgent pid=1473345) INFO:root:	task: avg	loss: 0.21256307	acc: 0.934
# (ParallelRecvDataAgent pid=1473232) INFO:root:epochs: 101, training task: 4
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 0	loss: 0.26898125	acc: 0.904
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 1	loss: 0.17943773	acc: 0.944
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 2	loss: 0.13171860	acc: 0.964
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 3	loss: 0.22460727	acc: 0.935
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: 4	loss: 0.32597036	acc: 0.924
# (ParallelRecvDataAgent pid=1473232) INFO:root:	task: avg	loss: 0.22614304	acc: 0.934
# (ParallelRecvDataAgent pid=1473413) INFO:root:epochs: 101, training task: 4
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 0	loss: 0.15863137	acc: 0.950
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 1	loss: 0.10405568	acc: 0.976
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 2	loss: 0.10027518	acc: 0.983
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 3	loss: 0.15995236	acc: 0.978
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: 4	loss: 0.19365283	acc: 0.942
# (ParallelRecvDataAgent pid=1473413) INFO:root:	task: avg	loss: 0.14331348	acc: 0.966
# (ParallelRecvDataAgent pid=1473537) INFO:root:epochs: 101, training task: 4
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 0	loss: 0.12823188	acc: 0.982
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 1	loss: 0.19517850	acc: 0.942
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 2	loss: 0.16182331	acc: 0.953
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 3	loss: 0.15930349	acc: 0.947
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: 4	loss: 0.21787627	acc: 0.943
# (ParallelRecvDataAgent pid=1473537) INFO:root:	task: avg	loss: 0.17248269	acc: 0.953
# (ParallelRecvDataAgent pid=1473233) INFO:root:epochs: 101, training task: 4
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 0	loss: 0.13014917	acc: 0.974
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 1	loss: 0.16291143	acc: 0.959
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 2	loss: 0.11954108	acc: 0.982
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 3	loss: 0.10845625	acc: 0.974
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: 4	loss: 0.17294922	acc: 0.988
# (ParallelRecvDataAgent pid=1473233) INFO:root:	task: avg	loss: 0.13880143	acc: 0.975
# (ParallelRecvDataAgent pid=1473231) INFO:root:epochs: 101, training task: 4
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 0	loss: 0.22546410	acc: 0.926
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 1	loss: 0.09929520	acc: 0.976
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 2	loss: 0.12467750	acc: 0.965
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 3	loss: 0.09947160	acc: 0.977
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: 4	loss: 0.16594830	acc: 0.960
# (ParallelRecvDataAgent pid=1473231) INFO:root:	task: avg	loss: 0.14297134	acc: 0.961
# training from 96 to 100
# (ParallelRecvDataAgent pid=1473474) INFO:root:epochs: 101, training task: 4
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 0	loss: 0.16466349	acc: 0.954
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 1	loss: 0.16574450	acc: 0.944
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 2	loss: 0.14717855	acc: 0.966
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 3	loss: 0.21700604	acc: 0.923
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: 4	loss: 0.20662001	acc: 0.969
# (ParallelRecvDataAgent pid=1473474) INFO:root:	task: avg	loss: 0.18024252	acc: 0.951

# %%
after_sharing_and_learn = fleet.eval_test(test_task_id)
df = pd.DataFrame(after_sharing_and_learn)
df.columns = df.columns.astype(str)

task_stats = df.agg(["mean", "std"])
plt.bar(task_stats.columns, task_stats.loc['mean'], yerr=task_stats.loc['std'], capsize=5, color='skyblue')
plt.xlabel('Tasks')
plt.ylabel('Average Performance')
plt.title('Baseline Performance')
plt.ylim(0.4, 1.0)  
plt.show()

# %%
task_stats
# Out:
#              0         1         2         3         4       avg
# mean  0.944674  0.955106  0.954811  0.953972  0.953426  0.952398
# std   0.028188  0.015982  0.028590  0.021974  0.019568  0.014670
