# %%
from shell.datasets.datasets import get_dataset
import numpy as np
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
from shell.utils.utils import seed_everything, viz_embedding
import torch
import subprocess
import torch.nn as nn
import torch
import os
from omegaconf import DictConfig
from shell.datasets.datasets import get_dataset
from shell.utils.utils import seed_everything
from pprint import pprint
from shell.fleet.network import TopologyGenerator
from shell.models.cnn_soft_lifelong_dynamic import CNNSoftLLDynamic
from shell.models.cnn import CNN
from shell.models.mlp import MLP
from shell.models.mlp_soft_lifelong_dynamic import MLPSoftLLDynamic
from shell.learners.er_dynamic import CompositionalDynamicER
from shell.learners.er_nocomponents import NoComponentsER
from shell.utils.experiment_utils import eval_net
from shell.utils.experiment_utils import setup_experiment
from sklearn.manifold import TSNE
import logging
import seaborn as sns
from shell.fleet.data_fleet import least_confidence_scorer, entropy_scorer, margin_scorer, cross_entropy_scorer
logging.basicConfig(level=logging.INFO)

# %%
data_cfg = {
    # "dataset_name": "kmnist",
    "dataset_name": "fashionmnist",
    "num_tasks": 1,
    "num_train_per_task": 128,
    "num_val_per_task": 102,
    "labels": np.array([1, 2]),
    'remap_labels': True,
}
dataset = get_dataset(**data_cfg)

task_id = 0
testloaders = {task: torch.utils.data.DataLoader(testset,
                                                 batch_size=128,
                                                 shuffle=False,
                                                 num_workers=0,
                                                 pin_memory=True,
                                                 ) for task, testset in enumerate(dataset.testset[:(task_id+1)])}

trainloader = torch.utils.data.DataLoader(dataset.trainset[task_id],
                                            batch_size=64,
                                            shuffle=True,
                                            num_workers=0,
                                            pin_memory=True,
                                            )

valset = dataset.valset[task_id]
# Out:
# INFO:root:Class sequence: [1 2]
# INFO:root:(128, 1, 28, 28)

# %%
net_cfg = {
    'depth': 2,
    'layer_size': 64,
    'num_init_tasks': -1,
    'i_size': 28,
    'num_classes': 2,
    'num_tasks': 1,
    'dropout': 0.0,
}

agent_cfg = {
    'memory_size': 64,
    'use_contrastive': True,
}
net = MLP(**net_cfg)
agent = NoComponentsER(net, **agent_cfg)

agent.train(trainloader, task_id=0, num_epochs=100, testloaders=testloaders,
                save_freq=1,
                train_mode='both')
# Out:
# INFO:root:epochs: 0, training task: 0
# INFO:root:	task: 0	loss: 6.248	acc: 0.500
# INFO:root:	task: avg	loss: 6.248	acc: 0.500
# INFO:root:epochs: 1, training task: 0
# INFO:root:	task: 0	loss: 6.166	acc: 0.500
# INFO:root:	task: avg	loss: 6.166	acc: 0.500
# INFO:root:epochs: 2, training task: 0
# INFO:root:	task: 0	loss: 6.132	acc: 0.500
# INFO:root:	task: avg	loss: 6.132	acc: 0.500
# INFO:root:epochs: 3, training task: 0
# INFO:root:	task: 0	loss: 6.094	acc: 0.500
# INFO:root:	task: avg	loss: 6.094	acc: 0.500
# INFO:root:epochs: 4, training task: 0
# INFO:root:	task: 0	loss: 6.020	acc: 0.500
# INFO:root:	task: avg	loss: 6.020	acc: 0.500
# INFO:root:epochs: 5, training task: 0
# INFO:root:	task: 0	loss: 5.989	acc: 0.500
# INFO:root:	task: avg	loss: 5.989	acc: 0.500
# INFO:root:epochs: 6, training task: 0
# INFO:root:	task: 0	loss: 5.933	acc: 0.500
# INFO:root:	task: avg	loss: 5.933	acc: 0.500
# INFO:root:epochs: 7, training task: 0
# INFO:root:	task: 0	loss: 5.927	acc: 0.500
# INFO:root:	task: avg	loss: 5.927	acc: 0.500
# INFO:root:epochs: 8, training task: 0
# INFO:root:	task: 0	loss: 5.903	acc: 0.504
# INFO:root:	task: avg	loss: 5.903	acc: 0.504
# INFO:root:epochs: 9, training task: 0
# INFO:root:	task: 0	loss: 5.874	acc: 0.527
# INFO:root:	task: avg	loss: 5.874	acc: 0.527
# INFO:root:epochs: 10, training task: 0
# INFO:root:	task: 0	loss: 5.885	acc: 0.641
# INFO:root:	task: avg	loss: 5.885	acc: 0.641
# INFO:root:epochs: 11, training task: 0
# INFO:root:	task: 0	loss: 5.861	acc: 0.782
# INFO:root:	task: avg	loss: 5.861	acc: 0.782
# INFO:root:epochs: 12, training task: 0
# INFO:root:	task: 0	loss: 5.844	acc: 0.826
# INFO:root:	task: avg	loss: 5.844	acc: 0.826
# INFO:root:epochs: 13, training task: 0
# INFO:root:	task: 0	loss: 5.801	acc: 0.806
# INFO:root:	task: avg	loss: 5.801	acc: 0.806
# INFO:root:epochs: 14, training task: 0
# INFO:root:	task: 0	loss: 5.861	acc: 0.803
# INFO:root:	task: avg	loss: 5.861	acc: 0.803
# INFO:root:epochs: 15, training task: 0
# INFO:root:	task: 0	loss: 5.803	acc: 0.860
# INFO:root:	task: avg	loss: 5.803	acc: 0.860
# INFO:root:epochs: 16, training task: 0
# INFO:root:	task: 0	loss: 5.804	acc: 0.900
# INFO:root:	task: avg	loss: 5.804	acc: 0.900
# INFO:root:epochs: 17, training task: 0
# INFO:root:	task: 0	loss: 5.780	acc: 0.923
# INFO:root:	task: avg	loss: 5.780	acc: 0.923
# INFO:root:epochs: 18, training task: 0
# INFO:root:	task: 0	loss: 5.771	acc: 0.935
# INFO:root:	task: avg	loss: 5.771	acc: 0.935
# INFO:root:epochs: 19, training task: 0
# INFO:root:	task: 0	loss: 5.780	acc: 0.935
# INFO:root:	task: avg	loss: 5.780	acc: 0.935
# INFO:root:epochs: 20, training task: 0
# INFO:root:	task: 0	loss: 5.747	acc: 0.935
# INFO:root:	task: avg	loss: 5.747	acc: 0.935
# INFO:root:epochs: 21, training task: 0
# INFO:root:	task: 0	loss: 5.731	acc: 0.932
# INFO:root:	task: avg	loss: 5.731	acc: 0.932
# INFO:root:epochs: 22, training task: 0
# INFO:root:	task: 0	loss: 5.724	acc: 0.928
# INFO:root:	task: avg	loss: 5.724	acc: 0.928
# INFO:root:epochs: 23, training task: 0
# INFO:root:	task: 0	loss: 5.760	acc: 0.925
# INFO:root:	task: avg	loss: 5.760	acc: 0.925
# INFO:root:epochs: 24, training task: 0
# INFO:root:	task: 0	loss: 5.755	acc: 0.930
# INFO:root:	task: avg	loss: 5.755	acc: 0.930
# INFO:root:epochs: 25, training task: 0
# INFO:root:	task: 0	loss: 5.718	acc: 0.943
# INFO:root:	task: avg	loss: 5.718	acc: 0.943
# INFO:root:epochs: 26, training task: 0
# INFO:root:	task: 0	loss: 5.714	acc: 0.948
# INFO:root:	task: avg	loss: 5.714	acc: 0.948
# INFO:root:epochs: 27, training task: 0
# INFO:root:	task: 0	loss: 5.743	acc: 0.953
# INFO:root:	task: avg	loss: 5.743	acc: 0.953
# INFO:root:epochs: 28, training task: 0
# INFO:root:	task: 0	loss: 5.711	acc: 0.952
# INFO:root:	task: avg	loss: 5.711	acc: 0.952
# INFO:root:epochs: 29, training task: 0
# INFO:root:	task: 0	loss: 5.726	acc: 0.953
# INFO:root:	task: avg	loss: 5.726	acc: 0.953
# INFO:root:epochs: 30, training task: 0
# INFO:root:	task: 0	loss: 5.667	acc: 0.954
# INFO:root:	task: avg	loss: 5.667	acc: 0.954
# INFO:root:epochs: 31, training task: 0
# INFO:root:	task: 0	loss: 5.687	acc: 0.956
# INFO:root:	task: avg	loss: 5.687	acc: 0.956
# INFO:root:epochs: 32, training task: 0
# INFO:root:	task: 0	loss: 5.686	acc: 0.961
# INFO:root:	task: avg	loss: 5.686	acc: 0.961
# INFO:root:epochs: 33, training task: 0
# INFO:root:	task: 0	loss: 5.681	acc: 0.967
# INFO:root:	task: avg	loss: 5.681	acc: 0.967
# INFO:root:epochs: 34, training task: 0
# INFO:root:	task: 0	loss: 5.688	acc: 0.960
# INFO:root:	task: avg	loss: 5.688	acc: 0.960
# INFO:root:epochs: 35, training task: 0
# INFO:root:	task: 0	loss: 5.706	acc: 0.955
# INFO:root:	task: avg	loss: 5.706	acc: 0.955
# INFO:root:epochs: 36, training task: 0
# INFO:root:	task: 0	loss: 5.686	acc: 0.952
# INFO:root:	task: avg	loss: 5.686	acc: 0.952
# INFO:root:epochs: 37, training task: 0
# INFO:root:	task: 0	loss: 5.664	acc: 0.952
# INFO:root:	task: avg	loss: 5.664	acc: 0.952
# INFO:root:epochs: 38, training task: 0
# INFO:root:	task: 0	loss: 5.667	acc: 0.953
# INFO:root:	task: avg	loss: 5.667	acc: 0.953
# INFO:root:epochs: 39, training task: 0
# INFO:root:	task: 0	loss: 5.662	acc: 0.960
# INFO:root:	task: avg	loss: 5.662	acc: 0.960
# INFO:root:epochs: 40, training task: 0
# INFO:root:	task: 0	loss: 5.671	acc: 0.968
# INFO:root:	task: avg	loss: 5.671	acc: 0.968
# INFO:root:epochs: 41, training task: 0
# INFO:root:	task: 0	loss: 5.647	acc: 0.969
# INFO:root:	task: avg	loss: 5.647	acc: 0.969
# INFO:root:epochs: 42, training task: 0
# INFO:root:	task: 0	loss: 5.641	acc: 0.968
# INFO:root:	task: avg	loss: 5.641	acc: 0.968
# INFO:root:epochs: 43, training task: 0
# INFO:root:	task: 0	loss: 5.649	acc: 0.960
# INFO:root:	task: avg	loss: 5.649	acc: 0.960
# INFO:root:epochs: 44, training task: 0
# INFO:root:	task: 0	loss: 5.659	acc: 0.956
# INFO:root:	task: avg	loss: 5.659	acc: 0.956
# INFO:root:epochs: 45, training task: 0
# INFO:root:	task: 0	loss: 5.660	acc: 0.952
# INFO:root:	task: avg	loss: 5.660	acc: 0.952
# INFO:root:epochs: 46, training task: 0
# INFO:root:	task: 0	loss: 5.644	acc: 0.952
# INFO:root:	task: avg	loss: 5.644	acc: 0.952
# INFO:root:epochs: 47, training task: 0
# INFO:root:	task: 0	loss: 5.657	acc: 0.957
# INFO:root:	task: avg	loss: 5.657	acc: 0.957
# INFO:root:epochs: 48, training task: 0
# INFO:root:	task: 0	loss: 5.640	acc: 0.965
# INFO:root:	task: avg	loss: 5.640	acc: 0.965
# INFO:root:epochs: 49, training task: 0
# INFO:root:	task: 0	loss: 5.668	acc: 0.970
# INFO:root:	task: avg	loss: 5.668	acc: 0.970
# INFO:root:epochs: 50, training task: 0
# INFO:root:	task: 0	loss: 5.651	acc: 0.971
# INFO:root:	task: avg	loss: 5.651	acc: 0.971
# INFO:root:epochs: 51, training task: 0
# INFO:root:	task: 0	loss: 5.639	acc: 0.971
# INFO:root:	task: avg	loss: 5.639	acc: 0.971
# INFO:root:epochs: 52, training task: 0
# INFO:root:	task: 0	loss: 5.617	acc: 0.970
# INFO:root:	task: avg	loss: 5.617	acc: 0.970
# INFO:root:epochs: 53, training task: 0
# INFO:root:	task: 0	loss: 5.623	acc: 0.965
# INFO:root:	task: avg	loss: 5.623	acc: 0.965
# INFO:root:epochs: 54, training task: 0
# INFO:root:	task: 0	loss: 5.639	acc: 0.959
# INFO:root:	task: avg	loss: 5.639	acc: 0.959
# INFO:root:epochs: 55, training task: 0
# INFO:root:	task: 0	loss: 5.604	acc: 0.966
# INFO:root:	task: avg	loss: 5.604	acc: 0.966
# INFO:root:epochs: 56, training task: 0
# INFO:root:	task: 0	loss: 5.598	acc: 0.971
# INFO:root:	task: avg	loss: 5.598	acc: 0.971
# INFO:root:epochs: 57, training task: 0
# INFO:root:	task: 0	loss: 5.612	acc: 0.975
# INFO:root:	task: avg	loss: 5.612	acc: 0.975
# INFO:root:epochs: 58, training task: 0
# INFO:root:	task: 0	loss: 5.606	acc: 0.976
# INFO:root:	task: avg	loss: 5.606	acc: 0.976
# INFO:root:epochs: 59, training task: 0
# INFO:root:	task: 0	loss: 5.590	acc: 0.976
# INFO:root:	task: avg	loss: 5.590	acc: 0.976
# INFO:root:epochs: 60, training task: 0
# INFO:root:	task: 0	loss: 5.592	acc: 0.976
# INFO:root:	task: avg	loss: 5.592	acc: 0.976
# INFO:root:epochs: 61, training task: 0
# INFO:root:	task: 0	loss: 5.576	acc: 0.974
# INFO:root:	task: avg	loss: 5.576	acc: 0.974
# INFO:root:epochs: 62, training task: 0
# INFO:root:	task: 0	loss: 5.578	acc: 0.973
# INFO:root:	task: avg	loss: 5.578	acc: 0.973
# INFO:root:epochs: 63, training task: 0
# INFO:root:	task: 0	loss: 5.592	acc: 0.973
# INFO:root:	task: avg	loss: 5.592	acc: 0.973
# INFO:root:epochs: 64, training task: 0
# INFO:root:	task: 0	loss: 5.573	acc: 0.974
# INFO:root:	task: avg	loss: 5.573	acc: 0.974
# INFO:root:epochs: 65, training task: 0
# INFO:root:	task: 0	loss: 5.556	acc: 0.975
# INFO:root:	task: avg	loss: 5.556	acc: 0.975
# INFO:root:epochs: 66, training task: 0
# INFO:root:	task: 0	loss: 5.585	acc: 0.976
# INFO:root:	task: avg	loss: 5.585	acc: 0.976
# INFO:root:epochs: 67, training task: 0
# INFO:root:	task: 0	loss: 5.573	acc: 0.976
# INFO:root:	task: avg	loss: 5.573	acc: 0.976
# INFO:root:epochs: 68, training task: 0
# INFO:root:	task: 0	loss: 5.550	acc: 0.976
# INFO:root:	task: avg	loss: 5.550	acc: 0.976
# INFO:root:epochs: 69, training task: 0
# INFO:root:	task: 0	loss: 5.557	acc: 0.976
# INFO:root:	task: avg	loss: 5.557	acc: 0.976
# INFO:root:epochs: 70, training task: 0
# INFO:root:	task: 0	loss: 5.554	acc: 0.974
# INFO:root:	task: avg	loss: 5.554	acc: 0.974
# INFO:root:epochs: 71, training task: 0
# INFO:root:	task: 0	loss: 5.554	acc: 0.973
# INFO:root:	task: avg	loss: 5.554	acc: 0.973
# INFO:root:epochs: 72, training task: 0
# INFO:root:	task: 0	loss: 5.571	acc: 0.974
# INFO:root:	task: avg	loss: 5.571	acc: 0.974
# INFO:root:epochs: 73, training task: 0
# INFO:root:	task: 0	loss: 5.541	acc: 0.975
# INFO:root:	task: avg	loss: 5.541	acc: 0.975
# INFO:root:epochs: 74, training task: 0
# INFO:root:	task: 0	loss: 5.577	acc: 0.976
# INFO:root:	task: avg	loss: 5.577	acc: 0.976
# INFO:root:epochs: 75, training task: 0
# INFO:root:	task: 0	loss: 5.555	acc: 0.977
# INFO:root:	task: avg	loss: 5.555	acc: 0.977
# INFO:root:epochs: 76, training task: 0
# INFO:root:	task: 0	loss: 5.517	acc: 0.977
# INFO:root:	task: avg	loss: 5.517	acc: 0.977
# INFO:root:epochs: 77, training task: 0
# INFO:root:	task: 0	loss: 5.532	acc: 0.976
# INFO:root:	task: avg	loss: 5.532	acc: 0.976
# INFO:root:epochs: 78, training task: 0
# INFO:root:	task: 0	loss: 5.548	acc: 0.974
# INFO:root:	task: avg	loss: 5.548	acc: 0.974
# INFO:root:epochs: 79, training task: 0
# INFO:root:	task: 0	loss: 5.526	acc: 0.974
# INFO:root:	task: avg	loss: 5.526	acc: 0.974
# INFO:root:epochs: 80, training task: 0
# INFO:root:	task: 0	loss: 5.530	acc: 0.975
# INFO:root:	task: avg	loss: 5.530	acc: 0.975
# INFO:root:epochs: 81, training task: 0
# INFO:root:	task: 0	loss: 5.516	acc: 0.976
# INFO:root:	task: avg	loss: 5.516	acc: 0.976
# INFO:root:epochs: 82, training task: 0
# INFO:root:	task: 0	loss: 5.505	acc: 0.976
# INFO:root:	task: avg	loss: 5.505	acc: 0.976
# INFO:root:epochs: 83, training task: 0
# INFO:root:	task: 0	loss: 5.502	acc: 0.976
# INFO:root:	task: avg	loss: 5.502	acc: 0.976
# INFO:root:epochs: 84, training task: 0
# INFO:root:	task: 0	loss: 5.511	acc: 0.976
# INFO:root:	task: avg	loss: 5.511	acc: 0.976
# INFO:root:epochs: 85, training task: 0
# INFO:root:	task: 0	loss: 5.511	acc: 0.976
# INFO:root:	task: avg	loss: 5.511	acc: 0.976
# INFO:root:epochs: 86, training task: 0
# INFO:root:	task: 0	loss: 5.501	acc: 0.975
# INFO:root:	task: avg	loss: 5.501	acc: 0.975
# INFO:root:epochs: 87, training task: 0
# INFO:root:	task: 0	loss: 5.519	acc: 0.975
# INFO:root:	task: avg	loss: 5.519	acc: 0.975
# INFO:root:epochs: 88, training task: 0
# INFO:root:	task: 0	loss: 5.497	acc: 0.976
# INFO:root:	task: avg	loss: 5.497	acc: 0.976
# INFO:root:epochs: 89, training task: 0
# INFO:root:	task: 0	loss: 5.494	acc: 0.978
# INFO:root:	task: avg	loss: 5.494	acc: 0.978
# INFO:root:epochs: 90, training task: 0
# INFO:root:	task: 0	loss: 5.488	acc: 0.978
# INFO:root:	task: avg	loss: 5.488	acc: 0.978
# INFO:root:epochs: 91, training task: 0
# INFO:root:	task: 0	loss: 5.482	acc: 0.978
# INFO:root:	task: avg	loss: 5.482	acc: 0.978
# INFO:root:epochs: 92, training task: 0
# INFO:root:	task: 0	loss: 5.485	acc: 0.978
# INFO:root:	task: avg	loss: 5.485	acc: 0.978
# INFO:root:epochs: 93, training task: 0
# INFO:root:	task: 0	loss: 5.481	acc: 0.978
# INFO:root:	task: avg	loss: 5.481	acc: 0.978
# INFO:root:epochs: 94, training task: 0
# INFO:root:	task: 0	loss: 5.476	acc: 0.978
# INFO:root:	task: avg	loss: 5.476	acc: 0.978
# INFO:root:epochs: 95, training task: 0
# INFO:root:	task: 0	loss: 5.487	acc: 0.978
# INFO:root:	task: avg	loss: 5.487	acc: 0.978
# INFO:root:epochs: 96, training task: 0
# INFO:root:	task: 0	loss: 5.470	acc: 0.978
# INFO:root:	task: avg	loss: 5.470	acc: 0.978
# INFO:root:epochs: 97, training task: 0
# INFO:root:	task: 0	loss: 5.452	acc: 0.980
# INFO:root:	task: avg	loss: 5.452	acc: 0.980
# INFO:root:epochs: 98, training task: 0
# INFO:root:	task: 0	loss: 5.480	acc: 0.981
# INFO:root:	task: avg	loss: 5.480	acc: 0.981
# INFO:root:epochs: 99, training task: 0
# INFO:root:	task: 0	loss: 5.472	acc: 0.981
# INFO:root:	task: avg	loss: 5.472	acc: 0.981
# INFO:root:epochs: 100, training task: 0
# INFO:root:	task: 0	loss: 5.459	acc: 0.981
# INFO:root:	task: avg	loss: 5.459	acc: 0.981
# INFO:root:epochs: 101, training task: 0
# INFO:root:	task: 0	loss: 5.487	acc: 0.981
# INFO:root:	task: avg	loss: 5.487	acc: 0.981

# %%
X_val, Y_val = valset.tensors

with torch.inference_mode():
    X_val = X_val.to(net.device)
    Y_val = Y_val.to(net.device)
    logits = agent.net(X_val, task_id=0)
    Y_hat = logits.argmax(dim=1)
    acc = (Y_hat == Y_val).float().mean()
    print(acc)
# Out:
# tensor(0.9804, device='cuda:0')

# %%
scorer = {
    'least_confidence': least_confidence_scorer,
    'entropy': entropy_scorer,
    'margin': margin_scorer,
    'cross_entropy': cross_entropy_scorer,
}


scores = {}
for name, score_fn in scorer.items():
    scores[name] = score_fn(logits, Y_val)

scores
# Out:
# {'least_confidence': tensor([-0.6356, -0.6111, -0.6874, -0.6510, -0.6992, -0.6230, -0.6490, -0.7336,
#          -0.6829, -0.7260, -0.6694, -0.7159, -0.7111, -0.7010, -0.7050, -0.6344,
#          -0.7095, -0.6563, -0.6814, -0.7231, -0.6496, -0.5599, -0.7389, -0.6218,
#          -0.7236, -0.6313, -0.7094, -0.5976, -0.6270, -0.6410, -0.6943, -0.6268,
#          -0.6266, -0.6402, -0.7235, -0.6296, -0.6803, -0.6161, -0.6233, -0.6335,
#          -0.7279, -0.6422, -0.6232, -0.6957, -0.6183, -0.7378, -0.5689, -0.7267,
#          -0.6171, -0.6542, -0.5510, -0.5917, -0.7303, -0.6216, -0.5953, -0.6317,
#          -0.6958, -0.7131, -0.6402, -0.7086, -0.6302, -0.5276, -0.6440, -0.6246,
#          -0.6208, -0.6292, -0.7375, -0.6323, -0.6630, -0.6260, -0.7198, -0.7184,
#          -0.7124, -0.6057, -0.6358, -0.6211, -0.6423, -0.6490, -0.6311, -0.5891,
#          -0.6294, -0.7069, -0.5893, -0.6919, -0.7067, -0.6380, -0.6145, -0.7002,
#          -0.6330, -0.7146, -0.6212, -0.6433, -0.6469, -0.6033, -0.6341, -0.6191,
#          -0.6809, -0.6091, -0.6306, -0.7295, -0.7102, -0.7057], device='cuda:0'),
#  'entropy': tensor([0.6559, 0.6682, 0.6211, 0.6468, 0.6115, 0.6626, 0.6481, 0.5796, 0.6247,
#          0.5872, 0.6346, 0.5968, 0.6012, 0.6101, 0.6066, 0.6566, 0.6026, 0.6435,
#          0.6258, 0.5900, 0.6477, 0.6860, 0.5742, 0.6632, 0.5895, 0.6582, 0.6027,
#          0.6740, 0.6605, 0.6529, 0.6156, 0.6606, 0.6607, 0.6533, 0.5896, 0.6592,
#          0.6267, 0.6659, 0.6624, 0.6571, 0.5853, 0.6522, 0.6625, 0.6145, 0.6649,
#          0.5754, 0.6836, 0.5865, 0.6655, 0.6448, 0.6879, 0.6762, 0.5829, 0.6633,
#          0.6749, 0.6580, 0.6144, 0.5993, 0.6533, 0.6034, 0.6589, 0.6916, 0.6511,
#          0.6618, 0.6637, 0.6594, 0.5756, 0.6577, 0.6390, 0.6610, 0.5931, 0.5944,
#          0.6000, 0.6706, 0.6558, 0.6635, 0.6521, 0.6481, 0.6584, 0.6772, 0.6593,
#          0.6049, 0.6771, 0.6175, 0.6051, 0.6545, 0.6667, 0.6107, 0.6573, 0.5980,
#          0.6635, 0.6515, 0.6493, 0.6716, 0.6568, 0.6645, 0.6262, 0.6691, 0.6586,
#          0.5838, 0.6020, 0.6060], device='cuda:0'),
#  'margin': tensor([-0.5562, -0.4520, -0.7882, -0.6237, -0.8436, -0.5024, -0.6147, -1.0131,
#          -0.7672, -0.9745, -0.7054, -0.9240, -0.9007, -0.8518, -0.8712, -0.5512,
#          -0.8929, -0.6467, -0.7602, -0.9597, -0.6174, -0.2407, -1.0401, -0.4973,
#          -0.9624, -0.5379, -0.8925, -0.3956, -0.5196, -0.5795, -0.8205, -0.5185,
#          -0.5178, -0.5761, -0.9620, -0.5306, -0.7549, -0.4731, -0.5037, -0.5471,
#          -0.9842, -0.5847, -0.5033, -0.8268, -0.4824, -1.0344, -0.2775, -0.9779,
#          -0.4771, -0.6375, -0.2047, -0.3710, -0.9963, -0.4963, -0.3861, -0.5396,
#          -0.8272, -0.9107, -0.5762, -0.8885, -0.5330, -0.1105, -0.5928, -0.5090,
#          -0.4928, -0.5287, -1.0332, -0.5420, -0.6769, -0.5152, -0.9435, -0.9367,
#          -0.9072, -0.4294, -0.5573, -0.4941, -0.5856, -0.6145, -0.5368, -0.3602,
#          -0.5297, -0.8802, -0.3612, -0.8091, -0.8793, -0.5668, -0.4663, -0.8482,
#          -0.5452, -0.9178, -0.4948, -0.5895, -0.6056, -0.4193, -0.5496, -0.4859,
#          -0.7579, -0.4436, -0.5348, -0.9920, -0.8963, -0.8745], device='cuda:0'),
#  'cross_entropy': tensor([0.4532, 0.4925, 0.3748, 0.4292, 0.3578, 0.4732, 0.4323, 0.3098, 0.3814,
#          0.3202, 0.4014, 0.3343, 0.3409, 0.3553, 0.3496, 0.4550, 0.3432, 0.4212,
#          0.3836, 0.3243, 0.4314, 0.5800, 0.3026, 0.4751, 0.3235, 0.4599, 0.3433,
#          0.5148, 0.4667, 0.4448, 0.3648, 0.4671, 0.4674, 0.4460, 0.3236, 0.4626,
#          0.3853, 0.4843, 0.4727, 0.4566, 0.3175, 0.4429, 0.4728, 0.3629, 0.4808,
#          0.3041, 0.5640, 0.3193, 0.4828, 0.4244, 0.8008, 0.5248, 0.3143, 0.4755,
#          0.5186, 0.4593, 0.3627, 0.3381, 0.4460, 0.3445, 0.4617, 0.7499, 0.4401,
#          0.4707, 0.4768, 0.4633, 0.3044, 0.4584, 0.4109, 0.4684, 0.3288, 0.3307,
#          0.3391, 0.5013, 0.4528, 0.4763, 0.4426, 0.4324, 0.4604, 0.5292, 0.4630,
#          0.3469, 0.5288, 0.3683, 0.3472, 0.4494, 0.4869, 0.3564, 0.4572, 0.3360,
#          0.4760, 0.4412, 0.4355, 0.5053, 0.4556, 0.4794, 0.3843, 0.4957, 0.4611,
#          0.3154, 0.3422, 0.3486], device='cuda:0')}

# %%
top_k = 10
# for each name, get the top k indices with their scores, plot them annotated with their scores
for name, score in scores.items():
    top_k_idx = score.topk(top_k)[1]
    top_k_scores = score[top_k_idx]
    top_k_images = X_val[top_k_idx]
    top_k_images = top_k_images.view(-1, 1, 28, 28)
    top_k_images = make_grid(top_k_images, nrow=5, padding=2, pad_value=1)
    plt.imshow(top_k_images.cpu().permute(1, 2, 0))
    plt.title(name)
    # annotate the images with their scores
    for i in range(top_k):
        plt.annotate(f"{top_k_scores[i].item():.3f}", (i*28, 0), color='red')
    plt.show()

# %%
top_k = 10

agreements = np.zeros((len(scores), len(scores)))
# compute the agreement rate between pairs of scorers
for name1, score1 in scores.items():
    for name2, score2 in scores.items():
        if name1 == name2:
            continue
        # agreement is defined as the size of the intersection of the top k indices
        top_k_idx1 = score1.topk(top_k)[1]
        top_k_idx2 = score2.topk(top_k)[1]
        agreement = len(set(top_k_idx1.tolist()) & set(top_k_idx2.tolist()))
        print(f"{name1} and {name2} agree on >> {agreement} / {top_k} images")
        agreements[list(scores.keys()).index(name1), list(scores.keys()).index(name2)] = agreement
# Out:
# least_confidence and entropy agree on >> 10 / 10 images
# least_confidence and margin agree on >> 10 / 10 images
# least_confidence and cross_entropy agree on >> 10 / 10 images
# entropy and least_confidence agree on >> 10 / 10 images
# entropy and margin agree on >> 10 / 10 images
# entropy and cross_entropy agree on >> 10 / 10 images
# margin and least_confidence agree on >> 10 / 10 images
# margin and entropy agree on >> 10 / 10 images
# margin and cross_entropy agree on >> 10 / 10 images
# cross_entropy and least_confidence agree on >> 10 / 10 images
# cross_entropy and entropy agree on >> 10 / 10 images
# cross_entropy and margin agree on >> 10 / 10 images

# %%
agreements
# Out:
# array([[ 0., 10., 10., 10.],
#        [10.,  0., 10., 10.],
#        [10., 10.,  0., 10.],
#        [10., 10., 10.,  0.]])

# %%
# NOTE: somehow cross entropy is not agreeing with anyone??? Might be the case that it is just confidently wrong.

# %%
# import torchvision.transforms as transforms

# def resize(img, score):
#     # img.shape = (1, 28, 28) and is a numpy array
#     # score is a float
#     img = torch.tensor(img)
#     trans = transforms.Resize((int(28*score)+5, int(28*score)+5))
#     img = trans(img)
#     return img

# plt.figure(figsize=(20, 10))
# _scores = scores['least_confidence']
# # normalize scores to [0, 1]
# _scores = (_scores - _scores.min()) / (_scores.max() - _scores.min())

# X_val_resized = []
# for img, score in zip(X_val, _scores):
#     X_val_resized.append(resize(img, score)) # [1, h_new, w_new]


# max_h = max([img.shape[1] for img in X_val_resized])
# min_h = min([img.shape[1] for img in X_val_resized])
# print(min_h, max_h)


# # visualize using make_grid
# X_val_resized = [torch.nn.functional.pad(img, (0, max_h-img.shape[1], 0, max_h-img.shape[2])) for img in X_val_resized]
# X_val_resized = torch.stack(X_val_resized)

# from torchvision.utils import make_grid
# grid = make_grid(X_val_resized, nrow=10).cpu()
# plt.imshow(grid.permute(1, 2, 0),)


# plt.figure(figsize=(20, 10))
# _scores = scores['entropy']
# # normalize scores to [0, 1]
# _scores = (_scores - _scores.min()) / (_scores.max() - _scores.min())

# X_val_resized = []
# for img, score in zip(X_val, _scores):
#     X_val_resized.append(resize(img, score)) # [1, h_new, w_new]


# max_h = max([img.shape[1] for img in X_val_resized])
# min_h = min([img.shape[1] for img in X_val_resized])
# print(min_h, max_h)


# # visualize using make_grid
# X_val_resized = [torch.nn.functional.pad(img, (0, max_h-img.shape[1], 0, max_h-img.shape[2])) for img in X_val_resized]
# X_val_resized = torch.stack(X_val_resized)

# from torchvision.utils import make_grid
# grid = make_grid(X_val_resized, nrow=10).cpu()
# plt.imshow(grid.permute(1, 2, 0))
